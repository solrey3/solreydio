# %%
from bs4 import BeautifulSoup
import requests
import pymongo
from splinter import Browser
import pandas as pd
import time

# %%
csv_file = "150ishFavoriteAlbums.csv"

# %%
albums150 = pd.read_csv(csv_file)
albums150
# Out:
#      rank                     artist                       album  \
# 0     NaN              Frank Sinatra  Songs for Swingin’ Lovers!
# 1     NaN             Duke Ellington        Ellington at Newport
# 2     NaN                Miles Davis           Birth of the Cool
# 3     NaN             Billie Holiday               Lady In Satin
# 4     6.0                Miles Davis                Kind Of Blue
# ..    ...                        ...                         ...
# 163   NaN                 Kanye West                      Yeezus
# 164  36.0                St. Vincent                 St. Vincent
# 165   NaN  D’Angelo and the Vanguard               Black Messiah
# 166   NaN             Kendrick Lamar         To Pimp A Butterfly
# 167   NaN          Car Seat Headrest             Teens of Denial
#
#                                          wikipedia_url release_date
# 0    https://en.wikipedia.org/wiki/Songs_for_Swingi...   1956-03-05
# 1    https://en.wikipedia.org/wiki/Ellington_at_New...   1956-07-07
# 2      https://en.wikipedia.org/wiki/Birth_of_the_Cool         1957
# 3          https://en.wikipedia.org/wiki/Lady_in_Satin      1958-06
# 4           https://en.wikipedia.org/wiki/Kind_of_Blue   1959-08-17
# ..                                                 ...          ...
# 163               https://en.wikipedia.org/wiki/Yeezus   2013-06-18
# 164  https://en.wikipedia.org/wiki/St._Vincent_(album)   2014-02-24
# 165  https://en.wikipedia.org/wiki/Black_Messiah_(a...   2014-12-15
# 166  https://en.wikipedia.org/wiki/To_Pimp_a_Butterfly   2015-03-15
# 167      https://en.wikipedia.org/wiki/Teens_of_Denial   2016-05-20
#
# [168 rows x 5 columns]

# %%
favoritealbums_df = pd.DataFrame({"artist": albums150.artist, "album": albums150.album, "wikipedia_url": albums150.wikipedia_url, "release_date": albums150.release_date})
favoritealbums_df.to_json('favoritealbums.json', orient='records')
favoritealbums_df
# Out:
#                         artist                       album  \
# 0                Frank Sinatra  Songs for Swingin’ Lovers!
# 1               Duke Ellington        Ellington at Newport
# 2                  Miles Davis           Birth of the Cool
# 3               Billie Holiday               Lady In Satin
# 4                  Miles Davis                Kind Of Blue
# ..                         ...                         ...
# 163                 Kanye West                      Yeezus
# 164                St. Vincent                 St. Vincent
# 165  D’Angelo and the Vanguard               Black Messiah
# 166             Kendrick Lamar         To Pimp A Butterfly
# 167          Car Seat Headrest             Teens of Denial
#
#                                          wikipedia_url release_date
# 0    https://en.wikipedia.org/wiki/Songs_for_Swingi...   1956-03-05
# 1    https://en.wikipedia.org/wiki/Ellington_at_New...   1956-07-07
# 2      https://en.wikipedia.org/wiki/Birth_of_the_Cool         1957
# 3          https://en.wikipedia.org/wiki/Lady_in_Satin      1958-06
# 4           https://en.wikipedia.org/wiki/Kind_of_Blue   1959-08-17
# ..                                                 ...          ...
# 163               https://en.wikipedia.org/wiki/Yeezus   2013-06-18
# 164  https://en.wikipedia.org/wiki/St._Vincent_(album)   2014-02-24
# 165  https://en.wikipedia.org/wiki/Black_Messiah_(a...   2014-12-15
# 166  https://en.wikipedia.org/wiki/To_Pimp_a_Butterfly   2015-03-15
# 167      https://en.wikipedia.org/wiki/Teens_of_Denial   2016-05-20
#
# [168 rows x 4 columns]

# %%
pareto

favoritealbums_df
# Out:
#                         artist                       album  \
# 0                Frank Sinatra  Songs for Swingin’ Lovers!
# 1               Duke Ellington        Ellington at Newport
# 2                  Miles Davis           Birth of the Cool
# 3               Billie Holiday               Lady In Satin
# 4                  Miles Davis                Kind Of Blue
# ..                         ...                         ...
# 162                 Kanye West                      Yeezus
# 163                St. Vincent                 St. Vincent
# 164  D’Angelo and the Vanguard               Black Messiah
# 165             Kendrick Lamar         To Pimp A Butterfly
# 166          Car Seat Headrest             Teens of Denial
#
#                                          wikipedia_url release_date
# 0    https://en.wikipedia.org/wiki/Songs_for_Swingi...   1956-03-05
# 1    https://en.wikipedia.org/wiki/Ellington_at_New...   1956-07-07
# 2      https://en.wikipedia.org/wiki/Birth_of_the_Cool         1957
# 3          https://en.wikipedia.org/wiki/Lady_in_Satin      1958-06
# 4           https://en.wikipedia.org/wiki/Kind_of_Blue   1959-08-17
# ..                                                 ...          ...
# 162               https://en.wikipedia.org/wiki/Yeezus   2013-06-18
# 163  https://en.wikipedia.org/wiki/St._Vincent_(album)   2014-02-24
# 164  https://en.wikipedia.org/wiki/Black_Messiah_(a...   2014-12-15
# 165  https://en.wikipedia.org/wiki/To_Pimp_a_Butterfly   2015-03-15
# 166      https://en.wikipedia.org/wiki/Teens_of_Denial   2016-05-20
#
# [167 rows x 4 columns]
